# %%
import matplotlib.pyplot as plt
import keras_ocr

# %%
images = [
    keras_ocr.tools.read(url) for url in [
        'frames/1.png',
        'frames/2.png',
        'frames/3.png',
        'frames/4.png',
        'frames/5.png',
    ]
]

# %%
pipeline = keras_ocr.pipeline.Pipeline()
prediction_groups = pipeline.recognize(images)
# Out:
# Looking for C:\Users\Anjie\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\Anjie\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\Anjie\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\Anjie\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 23s 23s/step
# 12/12 [==============================] - 12s 941ms/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %%
print(prediction_groups[0][0][0])
# Out:
# ge
